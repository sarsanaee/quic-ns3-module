# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# create some randomly ddistributed data:
#data = np.random.randn(10000)
#data = np.loadtxt("second_flow_1Mbps.dat", skiprows=50)
data1 = np.loadtxt("second_flow_10Gbps_1.dat", skiprows=3)
data2 = np.loadtxt("second_flow_10Gbps_2.dat", skiprows=3)
data5 = np.loadtxt("second_flow_10Gbps_5.dat", skiprows=3)
data10 = np.loadtxt("second_flow_10Gbps_10.dat", skiprows=3)
data3 = np.loadtxt("second_flow_10Gbps_3.dat", skiprows=3)
data4 = np.loadtxt("second_flow_10Gbps_4.dat", skiprows=3)
data7 = np.loadtxt("second_flow_10Gbps_7.dat", skiprows=3)
data15 = np.loadtxt("second_flow_10Gbps_15.dat", skiprows=3)
data20 = np.loadtxt("second_flow_10Gbps_20.dat", skiprows=3)
data100 = np.loadtxt("second_flow_10Gbps_100.dat", skiprows=3)




#data700 = np.loadtxt("second_flow_700Mbps.dat", skiprows=50)
#data1000 = np.loadtxt("second_flow_1000Mbps.dat", skiprows=50)
#data10000 = np.loadtxt("second_flow_10000Mbps.dat", skiprows=50)



# sort the data:
data_sorted1 = np.sort(data1[:,0])/1000
data_sorted2 = np.sort(data2[:,0])/1000
data_sorted3 = np.sort(data3[:,0])/1000
data_sorted4 = np.sort(data4[:,0])/1000
data_sorted5 = np.sort(data5[:,0])/1000
data_sorted7 = np.sort(data7[:,0])/1000
data_sorted10 = np.sort(data10[:,0])/1000
data_sorted15 = np.sort(data15[:,0])/1000
data_sorted20 = np.sort(data20[:,0])/1000
data_sorted100 = np.sort(data100[:,0])/1000







# calculate the proportional values of samples
p1 = 1. * np.arange(len(data1)) / (len(data1) - 1)
p2 = 1. * np.arange(len(data2)) / (len(data2) - 1)
p3 = 1. * np.arange(len(data3)) / (len(data3) - 1)
p4 = 1. * np.arange(len(data4)) / (len(data4) - 1)
p5 = 1. * np.arange(len(data5)) / (len(data5) - 1)
p7 = 1. * np.arange(len(data7)) / (len(data7) - 1)
p10 = 1. * np.arange(len(data10)) / (len(data10) - 1)
p15 = 1. * np.arange(len(data15)) / (len(data15) - 1)
p20 = 1. * np.arange(len(data20)) / (len(data20) - 1)
p100 = 1. * np.arange(len(data100)) / (len(data100) - 1)
#p10000 = 1. * np.arange(len(data10000)) / (len(data10000) - 1)





# plot the sorted data:
fig = plt.figure()

#ax1 = fig.add_subplot(121)
#ax1.plot(p, data_sorted)
#ax1.set_xlabel('$p$')
#ax1.set_ylabel('$x$')

plt.xlim( (0.996, 1) )


ax2 = fig.add_subplot(111)
plt.title("Quic Behaviour for Different Service Times")
ax2.plot(p1, data_sorted1)
ax2.plot(p2, data_sorted2)
ax2.plot(p3, data_sorted3)
ax2.plot(p4, data_sorted4)
ax2.plot(p5, data_sorted5)
ax2.plot(p7, data_sorted7)
ax2.plot(p10, data_sorted10)
ax2.plot(p15, data_sorted15)
ax2.plot(p20, data_sorted20)
ax2.plot(p100, data_sorted100)


ax2.set_xlabel('$ECDF$')
ax2.set_ylabel('$Latency(us)$')
#ax2.legend(['10Mbps', '100Mbps', '200Mbps', '300Mbps' , '500Mbps' , '700Mbps', '1Gbps', '10Gbps'])
ax2.legend(['1us', '2us', '3us', '4us', '5us', '7us' , '10us', '15us', '20us', '100us'])



'''
plt.ylim( (0.99, 1) )
ax2 = fig.add_subplot(221)
plt.title("ECDF of QUIC Protocol")
#ax2.plot(data_sorted, p)
ax2.plot(data_sorted10,p10)
ax2.plot(data_sorted100,p100)
ax2.plot(data_sorted1000,p1000)
ax2.set_xlabel('$Latency(us)$')
ax2.set_ylabel('$p$')
ax2.legend(['10Mbps', '100Mbps','700Mbps', '1Gbps'])
'''

plt.savefig("service-time-quic-zoomed.png", format='png', dpi=300)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# create some randomly ddistributed data:
#data = np.random.randn(10000)
data = np.loadtxt("second_flow_1Mbps.dat", skiprows=50)
data10 = np.loadtxt("second_flow_10Mbps.dat", skiprows=50)
data100 = np.loadtxt("second_flow_100Mbps.dat", skiprows=50)
data200 = np.loadtxt("second_flow_200Mbps.dat", skiprows=50)
data300 = np.loadtxt("second_flow_300Mbps.dat", skiprows=50)
data500 = np.loadtxt("second_flow_500Mbps.dat", skiprows=50)
data700 = np.loadtxt("second_flow_700Mbps.dat", skiprows=50)
data1000 = np.loadtxt("second_flow_1000Mbps.dat", skiprows=50)
data10000 = np.loadtxt("second_flow_10000Mbps.dat", skiprows=50)


percentile = 95

data = data[data[:,0].argsort()]
data10 = data10[data10[:,0].argsort()]
data100 = data100[data100[:,0].argsort()]
data200 = data200[data200[:,0].argsort()]
data300 = data300[data300[:,0].argsort()]
data500 = data500[data500[:,0].argsort()]
data700 = data700[data700[:,0].argsort()]
data1000 = data1000[data1000[:,0].argsort()]
data10000 = data10000[data10000[:,0].argsort()]


# sort the data:
#data_sorted = np.sort(data[:,0])/1000000



#data_sorted10 = np.sort(data10[:,0])/1000000
#data_sorted100 = np.sort(data100[:,0])/1000000
#data_sorted200 = np.sort(data200[:,0])/1000000
#data_sorted300 = np.sort(data300[:,0])/1000000
#data_sorted500 = np.sort(data500[:,0])/1000000
#data_sorted700 = np.sort(data700[:,0])/1000000
#data_sorted1000 = np.sort(data1000[:,0])/1000000





index = int(percentile*len(data)/100)
index10 = int(percentile*len(data10)/100)
index100 = int(percentile*len(data100)/100)
index200 = int(percentile*len(data200)/100)
index300 = int(percentile*len(data300)/100)
index500 = int(percentile*len(data500)/100)
index700 = int(percentile*len(data700)/100)
index1000 = int(percentile*len(data1000)/100)
index10000 = int(percentile*len(data10000)/100)



# plot the sorted data:
fig = plt.figure()

#ax1 = fig.add_subplot(121)
#ax1.plot(p, data_sorted)
#ax1.set_xlabel('$p$')
#ax1.set_ylabel('$x$')



lat_thr = []
#lat_thr.append((data[index][0]/1000000,data[index][1]))
lat_thr.append((data10[index10][0], data10[index10][1]))
lat_thr.append((data100[index100][0], data100[index100][1]))
lat_thr.append((data200[index200][0], data200[index200][1]))
lat_thr.append((data300[index300][0], data300[index300][1]))
lat_thr.append((data500[index500][0], data500[index500][1]))
lat_thr.append((data700[index700][0], data700[index700][1]))
lat_thr.append((data1000[index1000][0], data1000[index1000][1]))
lat_thr.append((data10000[index10000][0], data10000[index10000][1]))


lat_thr = np.array(lat_thr)

print(lat_thr[:,0])
print(lat_thr[:,1])

ax2 = fig.add_subplot(111)
plt.title("$QUIC$")
#ax2.plot(lat_thr[:,1],lat_thr[:,0], marker="v")
ax2.plot(data10[:,1], data10[:,0]/1000)
ax2.plot(data100[:,1], data100[:,0]/1000)
ax2.plot(data200[:,1], data200[:,0]/1000)
ax2.plot(data300[:,1], data300[:,0]/1000)
ax2.plot(data500[:,1], data500[:,0]/1000)
ax2.plot(data700[:,1], data700[:,0]/1000)
ax2.plot(data1000[:,1], data1000[:,0]/1000)
ax2.plot(data10000[:,1], data10000[:,0]/1000)

ax2.set_xlabel('$Throughput(Mbps)$')
ax2.set_ylabel('$Latency(us)$')
ax2.legend(['10Mbps', '100Mbps', '200Mbps', '300Mbps' , '500Mbps' , '700Mbps', '1Gbps', '10Gbps'])

plt.savefig("quic-latency-throughput-" + str(percentile) + ".png", format='png', dpi=300)
# Out:
# [64800.  5920.  3359.  2266.  1344.   959.  2696.   463.]
# [1.98293e+00 1.94420e+01 3.89805e+01 5.89301e+01 1.20849e+02 1.69193e+02
#  2.76540e+02 1.77002e+04]

# %%
#Poisson Process


# create some randomly ddistributed data:
#data = np.random.randn(10000)
#data = np.loadtxt("second_flow_1Mbps.dat", skiprows=50)
data1 = np.loadtxt("first_flow_10Gbps_1_p.dat", skiprows=5)
data2 = np.loadtxt("first_flow_10Gbps_2_p.dat", skiprows=5)
data5 = np.loadtxt("first_flow_10Gbps_5_p.dat", skiprows=5)
data10 = np.loadtxt("first_flow_10Gbps_10_p.dat", skiprows=5)
data3 = np.loadtxt("first_flow_10Gbps_3_p.dat", skiprows=5)
data4 = np.loadtxt("first_flow_10Gbps_4_p.dat", skiprows=5)
data7 = np.loadtxt("first_flow_10Gbps_7_p.dat", skiprows=5)
data15 = np.loadtxt("first_flow_10Gbps_15_p.dat", skiprows=5)
data20 = np.loadtxt("first_flow_10Gbps_20_p.dat", skiprows=5)
data100 = np.loadtxt("first_flow_10Gbps_100_p.dat", skiprows=5)




#data700 = np.loadtxt("second_flow_700Mbps.dat", skiprows=50)
#data1000 = np.loadtxt("second_flow_1000Mbps.dat", skiprows=50)
#data10000 = np.loadtxt("second_flow_10000Mbps.dat", skiprows=50)



# sort the data:
data_sorted1 = np.sort(data1[:,0])/1000
data_sorted2 = np.sort(data2[:,0])/1000
data_sorted3 = np.sort(data3[:,0])/1000
data_sorted4 = np.sort(data4[:,0])/1000
data_sorted5 = np.sort(data5[:,0])/1000
data_sorted7 = np.sort(data7[:,0])/1000
data_sorted10 = np.sort(data10[:,0])/1000
data_sorted15 = np.sort(data15[:,0])/1000
data_sorted20 = np.sort(data20[:,0])/1000
data_sorted100 = np.sort(data100[:,0])/1000







# calculate the proportional values of samples
p1 = 1. * np.arange(len(data1)) / (len(data1) - 1)
p2 = 1. * np.arange(len(data2)) / (len(data2) - 1)
p3 = 1. * np.arange(len(data3)) / (len(data3) - 1)
p4 = 1. * np.arange(len(data4)) / (len(data4) - 1)
p5 = 1. * np.arange(len(data5)) / (len(data5) - 1)
p7 = 1. * np.arange(len(data7)) / (len(data7) - 1)
p10 = 1. * np.arange(len(data10)) / (len(data10) - 1)
p15 = 1. * np.arange(len(data15)) / (len(data15) - 1)
p20 = 1. * np.arange(len(data20)) / (len(data20) - 1)
p100 = 1. * np.arange(len(data100)) / (len(data100) - 1)
#p10000 = 1. * np.arange(len(data10000)) / (len(data10000) - 1)





# plot the sorted data:
fig = plt.figure()

#ax1 = fig.add_subplot(121)
#ax1.plot(p, data_sorted)
#ax1.set_xlabel('$p$')
#ax1.set_ylabel('$x$')

plt.xlim( (0.90, 1) )

my_x_ticks = [0.90, 0.92, 0.94, 0.95, 0.96, 0.98, 0.99, 0.999]
my_y_ticks = [0, 10, 20, 25 ,30, 40, 50]

ax2 = fig.add_subplot(111)
plt.title("Quic Behaviour for Different Mean Service Times Based on Poisson Process", fontsize=10)

plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)

ax2.plot(p1, data_sorted1)
ax2.plot(p2, data_sorted2)
ax2.plot(p3, data_sorted3)
ax2.plot(p4, data_sorted4)
ax2.plot(p5, data_sorted5)
ax2.plot(p7, data_sorted7)
ax2.plot(p10, data_sorted10)
ax2.plot(p15, data_sorted15)
ax2.plot(p20, data_sorted20)
ax2.plot(p100, data_sorted100)



ax2.set_xlabel('$ECDF$')
ax2.set_ylabel('$Latency(us)$')
#ax2.legend(['10Mbps', '100Mbps', '200Mbps', '300Mbps' , '500Mbps' , '700Mbps', '1Gbps', '10Gbps'])
ax2.legend(['1us', '2us', '3us', '4us', '5us', '7us' , '10us', '15us', '20us', '100us'], loc=3)

ax2.axvline(0.99, color='r', ls='--')
ax2.axvline(0.95, color='b', ls='--')
ax2.axvline(0.999, color='g', ls='--')


ax2.axhline(25, color='k', ls='--')

ax2.annotate('SLO for 5us\nservice time\nat 95 percentile', xy=(0.95, 25), xytext=(0.96, 15), 
             arrowprops=dict(facecolor='black', shrink=0.05))






'''
plt.ylim( (0.99, 1) )
ax2 = fig.add_subplot(221)
plt.title("ECDF of QUIC Protocol")
#ax2.plot(data_sorted, p)
ax2.plot(data_sorted10,p10)
ax2.plot(data_sorted100,p100)
ax2.plot(data_sorted1000,p1000)
ax2.set_xlabel('$Latency(us)$')
ax2.set_ylabel('$p$')
ax2.legend(['10Mbps', '100Mbps','700Mbps', '1Gbps'])
'''

plt.savefig("poisson_process_anotated_1.png", format='png', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-ada33a8a9aad> in <module>()
#      61
#      62 # plot the sorted data:
# ---> 63 fig = plt.figure()
#      64
#      65 #ax1 = fig.add_subplot(121)
#
# TypeError: 'Figure' object is not callable

# %%
#Throughput-Latency


# create some randomly ddistributed data:
#data = np.random.randn(10000)
#data = np.loadtxt("second_flow_1Mbps.dat", skiprows=50)


data1 = np.loadtxt("first_flow_10Gbps_1_p.dat", skiprows=5)
data2 = np.loadtxt("first_flow_10Gbps_2_p.dat", skiprows=5)
data3 = np.loadtxt("first_flow_10Gbps_3_p.dat", skiprows=5)
data4 = np.loadtxt("first_flow_10Gbps_4_p.dat", skiprows=5)
data5 = np.loadtxt("first_flow_10Gbps_5_p.dat", skiprows=5)
data7 = np.loadtxt("first_flow_10Gbps_7_p.dat", skiprows=5)
data10 = np.loadtxt("first_flow_10Gbps_10_p.dat", skiprows=5)
data15 = np.loadtxt("first_flow_10Gbps_15_p.dat", skiprows=5)
data20 = np.loadtxt("first_flow_10Gbps_20_p.dat", skiprows=5)
data100 = np.loadtxt("first_flow_10Gbps_100_p.dat", skiprows=5)
data1000 = np.loadtxt("first_flow_10Gbps_1000_p.dat", skiprows=5)

#data2 = np.loadtxt("second_flow_10Gbps_1_p.dat", skiprows=5)

#data_sorted5 = np.sort(data5[:,0])/1000

sorted_data1 = data1[data1[:,0].argsort()]
sorted_data2 = data2[data2[:,0].argsort()]
sorted_data3 = data3[data3[:,0].argsort()]
sorted_data4 = data4[data4[:,0].argsort()]
sorted_data5 = data5[data5[:,0].argsort()]
sorted_data7 = data7[data7[:,0].argsort()]
sorted_data10 = data10[data10[:,0].argsort()]
sorted_data15 = data15[data15[:,0].argsort()]
sorted_data20 = data20[data20[:,0].argsort()]
sorted_data100 = data100[data100[:,0].argsort()]
sorted_data1000 = data1000[data1000[:,0].argsort()]



# calculate the proportional values of samples

#p5 = 1. * np.arange(len(data5)) / (len(data5) - 1)


sorted_data1[:,0] = sorted_data1[:,0]/1000
sorted_data2[:,0] = sorted_data2[:,0]/1000
sorted_data3[:,0] = sorted_data3[:,0]/1000
sorted_data4[:,0] = sorted_data4[:,0]/1000
sorted_data5[:,0] = sorted_data5[:,0]/1000
sorted_data7[:,0] = sorted_data7[:,0]/1000
sorted_data10[:,0] = sorted_data10[:,0]/1000
sorted_data15[:,0] = sorted_data15[:,0]/1000
sorted_data20[:,0] = sorted_data20[:,0]/1000
sorted_data100[:,0] = sorted_data100[:,0]/1000
sorted_data1000[:,0] = sorted_data1000[:,0]/1000






# plot the sorted data:
fig = plt.figure()

plt.title("Maximum Throughput Achieving Based on SLO", fontsize=10)


ax1 = fig.add_subplot(111)
ax1.plot(sorted_data15[:,1], sorted_data15[:,0])
ax1.set_xlabel('$Throughput(Mbps)$')
ax1.set_ylabel('$Latency(us)$')
ax1.legend(['15us'])
ax1.axhline(75, color='r', ls='--')

#plt.xlim( (0.99, 1) )

plt.savefig("latency_throughput/throughput_latency_15.png", format='png', dpi=300)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
